# %% [markdown]
# <a href="https://colab.research.google.com/github/abril03-hervert/pandas/blob/main/VHA_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##universidad del mar##

# %% [markdown]
# #UNIVERSIDAD DEL MAR #
# ##CAMPUS PUERTO ANGEL##
# ##ALUMNA: ABRIL VARGAS HERVERT
# ##GRUPO: 302 B
# ##ORDINARIO DE PROGRAMACION
# ##3er PARCIAL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
"""https://raw.githubusercontent.com/abril03-hervert/pandas/main/VHA2.csv"""
'https://raw.githubusercontent.com/abril03-hervert/pandas/main/VHA2.csv'
# Out:
# 'https://raw.githubusercontent.com/abril03-hervert/pandas/main/VHA2.csv'

# %%
VHA_df = pd.read_csv('https://raw.githubusercontent.com/abril03-hervert/pandas/main/VHA2.csv')

# %%
VHA_df
# Out:
#       NOMBRE    APELLIDOS      SEXO   ...  3PARCIAL  ORDINARIO   PROMEDIO
# 0     ALICIA       BLANCO  FEMENINO   ...         1          6         NaN
# 1     ANTHONY     CABRERA  MASCULINO  ...         5          7         NaN
# 2       ISSAC        CRUZ  MASCULINO  ...         8          8         NaN
# 3      RAFAEL    ESPINOZA  MASCULINO  ...         8          5         NaN
# 4    SCARLETT    EZCURDIA  FEMENINO   ...         0          3         NaN
# 5     PAULINA      GARCIA  FEMENINO   ...        10          9         NaN
# 6       EDGAR      GARCIA  MASCULINO  ...         9          8         NaN
# 7      JOSSET  GUENDULAIN  FEMENINO   ...        10          7         NaN
# 8       DAVID   HERNANDEZ  MASCULINO  ...         7          5         NaN
# 9     NATALIA   HERNANDEZ  FEMENINO   ...        10          4         NaN
# 10   QUETZALI   HERNANDEZ  FEMENINO   ...         9          9         NaN
# 11      NOEMI    MARTINEZ  FEMENINO   ...         8          8         NaN
# ...

# %%
VHA_df['calificacion final'] = VHA_df [[' 1PRARCIAL ', ' 2PARCIAL ' , '3PARCIAL' , ' ORDINARIO ']].mean(axis=1)

# %%
VHA_df.head(23)
# Out:
#       NOMBRE    APELLIDOS      SEXO   ...  3PARCIAL  ORDINARIO   PROMEDIO
# 0     ALICIA       BLANCO  FEMENINO   ...         1          6         NaN
# 1     ANTHONY     CABRERA  MASCULINO  ...         5          7         NaN
# 2       ISSAC        CRUZ  MASCULINO  ...         8          8         NaN
# 3      RAFAEL    ESPINOZA  MASCULINO  ...         8          5         NaN
# 4    SCARLETT    EZCURDIA  FEMENINO   ...         0          3         NaN
# 5     PAULINA      GARCIA  FEMENINO   ...        10          9         NaN
# 6       EDGAR      GARCIA  MASCULINO  ...         9          8         NaN
# 7      JOSSET  GUENDULAIN  FEMENINO   ...        10          7         NaN
# 8       DAVID   HERNANDEZ  MASCULINO  ...         7          5         NaN
# 9     NATALIA   HERNANDEZ  FEMENINO   ...        10          4         NaN
# 10   QUETZALI   HERNANDEZ  FEMENINO   ...         9          9         NaN
# 11      NOEMI    MARTINEZ  FEMENINO   ...         8          8         NaN
# ...

# %%
##¿CUAL ES LA CALIFICACION FINAL DEL GRUPO?
VHA_df[' PROMEDIO '].mean()
# Out:
# nan

# %%
grouped_data = VHA_df.groupby('sexo')

# %%
##¿cuales son las estadisticas por sexo?
grouped_data
# Out:
# <bound method DataFrame.groupby of       NOMBRE    APELLIDOS      SEXO   ...  2PARCIAL   3PARCIAL  ORDINARIO
# 0     ALICIA       BLANCO  FEMENINO   ...          0         1           6
# 1     ANTHONY     CABRERA  MASCULINO  ...          8         5           7
# 2       ISSAC        CRUZ  MASCULINO  ...          8         8           8
# 3      RAFAEL    ESPINOZA  MASCULINO  ...          6         8           5
# 4    SCARLETT    EZCURDIA  FEMENINO   ...          2         0           3
# 5     PAULINA      GARCIA  FEMENINO   ...         10        10           9
# 6       EDGAR      GARCIA  MASCULINO  ...          5         9           8
# 7      JOSSET  GUENDULAIN  FEMENINO   ...         10        10           7
# 8       DAVID   HERNANDEZ  MASCULINO  ...          8         7           5
# 9     NATALIA   HERNANDEZ  FEMENINO   ...          9        10           4
# 10   QUETZALI   HERNANDEZ  FEMENINO   ...          7         9           9
# ...

# %%
##¿cual es la desviacion estandar del grupo?
VHA_df['calificacion final '].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'calificacion final '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-6e4bcdf063a0> in <module>()
# ...

# %%
##¿cual es la mayor calificacion final?
VHA_df['calificacion final'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'calificacion final'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-4198730b6e5b> in <module>()
# ...

# %% [markdown]
# ##¿que tipo de datos contiene el data frame?
# #surveys_df['record_id'].dtype
# #surveys_df['sex'].dtye
# #type(surveys_df)
# #print
